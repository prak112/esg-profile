# %% [markdown]
# # ALTERNATE approach
# > * use table from 'https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue'

# %% [markdown]
# ## ESG profile Key-Initiatives (KIs) from Companies' Annual reports
# > * Extract top global Companies list (from Report evaluated by PwC with Bloomberg)
# > * Extract KIs from Companys' Annual reports

# %%
# Import neccessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_html('https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue')[0].head()
# Out:
#   Rank                      Name     Industry      Revenue       Profit  \
#   Rank                      Name     Industry USD Millions USD Millions
# 0    1                   Walmart       Retail     $559,200      $19,742
# 1    2             Sinopec Group  Oil and gas     $407,009       $6,793
# 2    3                    Amazon       Retail     $386,064      $17,377
# 3    4                State Grid  Electricity     $383,906       $7,970
# 4    5  China National Petroleum  Oil and gas     $379,130       $4,433
#
#   Employees Headquarters[note 1]  Ref
#   Employees Headquarters[note 1]  Ref
# 0   2300000        United States  [4]
# 1    582648                China  [5]
# 2   1298000        United States  [6]
# 3    907677                China  [7]
# 4   1344410                China  [8]

# %%
# Table Data extraction, if HTML page was extracted

def extract_data(raw_html):

    data = []
    table = raw_html.find('table', attrs={'class':'fbs-table organization'})
    table_body = table.find('tbody')
    table_rows = table_body.findAll('tr')

    for row in table_rows:
        cols = row.find_all('td')
        cols = [element.text.strip() for element in row]
        data.append([element for element in cols if element])

    return data

# %%
# Group list of companies by sectors (https://en.wikipedia.org/wiki/List_of_companies_of_Finland)

companies_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_companies_of_Finland')[0]
companies_df.head()
# Out:
#           Name           Industry                 Sector Headquarters  \
# 0     Ahlstrom    Basic materials        Basic resources     Helsinki
# 1   Aktia Bank         Financials                  Banks     Helsinki
# 2   Alma Media  Consumer services             Publishing     Helsinki
# 3        Altia     Consumer goods  Distillers & vintners     Helsinki
# 4  Amer Sports     Consumer goods  Recreational products     Helsinki
#
#    Founded                Notes
# 0     1851      Fiber materials
# 1     1991              Finance
# 2     1849        Digital media
# 3     1999  Alcoholic beverages
# 4     1950   Sporting equipment

# %%
columns = companies_df.columns.to_list()
columns
# Out:
# ['Name', 'Industry', 'Sector', 'Headquarters', 'Founded', 'Notes']

# %%
# changing wrong column label, Sector --> Company

companies_df.columns = ['Company_Name', 'Industry', 'Company_Type', 'Headquarters', 'Founded', 'Notes']
companies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  87 non-null     object
#  1   Industry      87 non-null     object
#  2   Company_Type  87 non-null     object
#  3   Headquarters  87 non-null     object
#  4   Founded       87 non-null     int64
#  5   Notes         87 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 4.2+ KB

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Calculate Age of Companies in years w.r.t completed year (2020)

companies_df['Company_Age'] = companies_df['Founded'].apply(lambda yr: 2020 - yr)
companies_df.head()
# Out:
#   Company_Name           Industry           Company_Type Headquarters  \
# 0     Ahlstrom    Basic materials        Basic resources     Helsinki
# 1   Aktia Bank         Financials                  Banks     Helsinki
# 2   Alma Media  Consumer services             Publishing     Helsinki
# 3        Altia     Consumer goods  Distillers & vintners     Helsinki
# 4  Amer Sports     Consumer goods  Recreational products     Helsinki
#
#    Founded                Notes  Company_Age
# 0     1851      Fiber materials          169
# 1     1991              Finance           29
# 2     1849        Digital media          171
# 3     1999  Alcoholic beverages           21
# 4     1950   Sporting equipment           70

# %%
# Companies greater than & less than or equal to 100 years

age_g100 = companies_df.loc[companies_df['Company_Age']>100].Company_Name.to_list()
age_le100 = companies_df.loc[companies_df['Company_Age']<=100].Company_Name.to_list()
print(f"Companies older than 100 years:\n{age_g100}\n\nCompanies younger than 100 years:\n{age_le100}")
# Out:
# Companies older than 100 years:
# ['Ahlstrom', 'Alma Media', 'Bank of Åland', 'Elisa', 'Fazer', 'Fiskars', 'Hartwall', 'HKScan', 'Kone', 'Lemminkäinen Group', 'Nokia', 'Nokian Jalkineet', 'Olvi', 'OP Financial Group', 'S Group', 'Stockmann', 'Suominen Corporation', 'Tikkurila', 'Valio', 'VR', 'Wärtsilä', 'Woikoski', 'YIT']
#
# Companies younger than 100 years:
# ['Aktia Bank', 'Altia', 'Amer Sports', 'Basware', 'Bittium', 'Cargotec', 'Codenomicon', 'DNA Oyj', 'Eckerö Line', 'EKS', 'Fingrid', 'Finnair', 'Finnlines', 'Fortum', 'F-Secure', 'Hesburger', 'Holvi', 'Huhtamäki', 'Kemira', 'Kemppi', 'Kesko', 'Konecranes', 'Kotipizza', 'Marimekko', 'Metsä Group', 'Metso', 'Neste', 'Nokia Networks', 'Nokian Tyres', 'Outokumpu', 'Outotec', 'Patria', 'Planmeca', 'Pohjolan Voima', 'Polar Electro', 'Ponsse Corporation', 'Posiva', 'Pöyry', 'Process Vision', 'Raisio Group', 'Rautaruukki', 'Rovio Entertainment', 'Sampo Group', 'Sanoma', 'Silja Line', 'Sisu Auto', 'Solidium', 'SSH Communications Security', 'St1', 'Stenfors', 'Stonesoft Corporation', 'Stora Enso', 'Supercell', 'Suunto', 'Talvivaara Mining Company', 'Tieto', 'UPM-Kymmene', 'Vacon', 'Vaisala', 'Valmet Automotive', 'Valmet', 'Valtra', 'Verkkokauppa.com', 'Viking Line']

# %%
#! pip install google --quiet

# %%
def company_reports(companies):
    """
    Provides a list of links related to companies' sustainability reports, if available

    Args:
    companies - list of companies
    
    Returns:
    company_links - list of websites related to companies' list provided
    """

    from googlesearch import search
    
    company_links = []

    for company in companies:
        query = f"annual sustainability report of {company}"
        try:
            for link in search(query, lang='fi', tld='.fi', country='finland', num=10, start=1, stop=10, pause=2.5):
                company_links.append(link)
        except UnicodeError:
            print(f"Excluding {company} due to name error")

    return company_links

# %%
g100_links = company_reports(age_g100) # age of companies greater than 100 years
le100_links = company_reports(age_le100) # age of companies less than or equal to 100 years

print(g100_links, '\n', le100_links)
# Out:
# Excluding Ahlstrom due to name error
# Excluding Alma Media due to name error
# Excluding Bank of Åland due to name error
# Excluding Elisa due to name error
# Excluding Fazer due to name error
# Excluding Fiskars due to name error
# Excluding Hartwall due to name error
# Excluding HKScan due to name error
# Excluding Kone due to name error
# Excluding Lemminkäinen Group due to name error
# Excluding Nokia due to name error
# Excluding Nokian Jalkineet due to name error
# Excluding Olvi due to name error
# Excluding OP Financial Group due to name error
# Excluding S Group due to name error
# Excluding Stockmann due to name error
# Excluding Suominen Corporation due to name error
# Excluding Tikkurila due to name error
# Excluding Valio due to name error
# Excluding VR due to name error
# Excluding Wärtsilä due to name error
# Excluding Woikoski due to name error
# Excluding YIT due to name error
# Excluding Aktia Bank due to name error
# Excluding Altia due to name error
# Excluding Amer Sports due to name error
# Excluding Basware due to name error
# Excluding Bittium due to name error
# Excluding Cargotec due to name error
# Excluding Codenomicon due to name error
# Excluding DNA Oyj due to name error
# Excluding Eckerö Line due to name error
# Excluding EKS due to name error
# Excluding Fingrid due to name error
# Excluding Finnair due to name error
# Excluding Finnlines due to name error
# Excluding Fortum due to name error
# Excluding F-Secure due to name error
# Excluding Hesburger due to name error
# Excluding Holvi due to name error
# Excluding Huhtamäki due to name error
# Excluding Kemira due to name error
# Excluding Kemppi due to name error
# Excluding Kesko due to name error
# Excluding Konecranes due to name error
# Excluding Kotipizza due to name error
# Excluding Marimekko due to name error
# Excluding Metsä Group due to name error
# Excluding Metso due to name error
# Excluding Neste due to name error
# Excluding Nokia Networks due to name error
# Excluding Nokian Tyres due to name error
# Excluding Outokumpu due to name error
# Excluding Outotec due to name error
# Excluding Patria due to name error
# Excluding Planmeca due to name error
# Excluding Pohjolan Voima due to name error
# Excluding Polar Electro due to name error
# Excluding Ponsse Corporation due to name error
# Excluding Posiva due to name error
# Excluding Pöyry due to name error
# Excluding Process Vision due to name error
# Excluding Raisio Group due to name error
# Excluding Rautaruukki due to name error
# Excluding Rovio Entertainment due to name error
# Excluding Sampo Group due to name error
# Excluding Sanoma due to name error
# Excluding Silja Line due to name error
# Excluding Sisu Auto due to name error
# Excluding Solidium due to name error
# Excluding SSH Communications Security due to name error
# Excluding St1 due to name error
# Excluding Stenfors due to name error
# Excluding Stonesoft Corporation due to name error
# Excluding Stora Enso due to name error
# Excluding Supercell due to name error
# Excluding Suunto due to name error
# Excluding Talvivaara Mining Company due to name error
# Excluding Tieto due to name error
# Excluding UPM-Kymmene due to name error
# Excluding Vacon due to name error
# Excluding Vaisala due to name error
# Excluding Valmet Automotive due to name error
# Excluding Valmet due to name error
# Excluding Valtra due to name error
# Excluding Verkkokauppa.com due to name error
# Excluding Viking Line due to name error
# []
#  []

# %%
# Companies visualized w.r.t. type of Industries

companies_df.groupby('Industry')['Company_Type'].count().plot(kind='barh', figsize=(20,10), title='Company types under different Industries')
#sns.catplot(x='Sector', hue='Industry', col='Founded', data=companies_df, kind='count', height=7, aspect=0.8)

# %%
# Company_Types visualized specifically w.r.t. types of Industry

plt.figure(figsize=(20,10))
sns.countplot(y='Company_Name', hue='Industry', data=companies_df)
